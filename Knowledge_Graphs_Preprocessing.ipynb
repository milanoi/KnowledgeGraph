# %% [markdown]
# # 1. Knowledge Graphs - Data Preprocessing

# %% [markdown]
# ## 1.1. Load Data

# %%
import pandas as pd

# %%
#Mounting my personal google drive where the dataset is stored so that I can use it directly in Colab
from google.colab import drive

drive.mount('/content/gdrive'

# %%
#Load the dataset obtained from Kaggle
movie_plots_data = pd.read_csv('/content/gdrive/MyDrive/Shopify Application/wiki_movie_plots_deduped.csv')
print(movie_plots_data.shape)
# Out:
# (34886, 8)

# %% [markdown]
# ## 1.2. Select Subset

# %%
movie_plots_data_selection = movie_plots_data[movie_plots_data['Release Year'] >= 2005]

# %%
plots = movie_plots_data_selection.Plot

# %%
plots.head()
# Out:
# 14591    Andy Stitzer is a 40-year-old virgin who lives...
# 14592    51 Birch Street is the first-person account of...
# 14593    Max is a lonely child in the suburbs of Austin...
# 14594    In 2011, a deadly pathogenic virus has killed ...
# 14595    In 1974, Ronald DeFeo Jr. murdered his family ...
# Name: Plot, dtype: object

# %% [markdown]
# ## 1.3. Split Movie Plots Into Phrases

# %%
phrases = []
for plot in plots.head(1000):
    phrases_all = plot.split('.')
    phrases_filtered = [p.strip() for p in phrases_all if p.strip() and len(p.strip()) > 3]
    phrases += phrases_filtered

# %%
# !pip install spacy
# !pip install textacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (21.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.0.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting textacy
#   Downloading textacy-0.12.0-py3-none-any.whl (208 kB)
#      |████████████████████████████████| 208 kB 7.4 MB/s
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.8/dist-packages (from textacy) (2.23.0)
# Requirement already satisfied: tqdm>=4.19.6 in /usr/local/lib/python3.8/dist-packages (from textacy) (4.64.1)
# Requirement already satisfied: catalogue~=2.0 in /usr/local/lib/python3.8/dist-packages (from textacy) (2.0.8)
# Requirement already satisfied: spacy>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from textacy) (3.4.4)
# Requirement already satisfied: scikit-learn>=0.19.0 in /usr/local/lib/python3.8/dist-packages (from textacy) (1.0.2)
# Requirement already satisfied: joblib>=0.13.0 in /usr/local/lib/python3.8/dist-packages (from textacy) (1.2.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.8/dist-packages (from textacy) (1.7.3)
# Requirement already satisfied: cachetools>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from textacy) (5.2.0)
# Collecting cytoolz>=0.10.1
#   Downloading cytoolz-0.12.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 52.8 MB/s
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.8/dist-packages (from textacy) (2.8.8)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.8/dist-packages (from textacy) (1.21.6)
# Collecting jellyfish>=0.8.0
#   Downloading jellyfish-0.9.0.tar.gz (132 kB)
#      |████████████████████████████████| 132 kB 42.9 MB/s
# Collecting pyphen>=0.10.0
#   Downloading pyphen-0.13.2-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 54.4 MB/s
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from cytoolz>=0.10.1->textacy) (0.12.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.10.0->textacy) (2022.12.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.10.0->textacy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.10.0->textacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.10.0->textacy) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.19.0->textacy) (3.1.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.0->textacy) (1.0.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.0->textacy) (0.10.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.0->textacy) (8.1.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.0->textacy) (2.11.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.0->textacy) (57.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.0->textacy) (1.10.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.0->textacy) (2.0.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.0->textacy) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.0->textacy) (2.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.0->textacy) (21.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.0->textacy) (0.10.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.0->textacy) (3.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.0->textacy) (3.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.0->textacy) (0.7.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.0->textacy) (6.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.0->textacy) (1.0.9)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy>=3.0.0->textacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy>=3.0.0->textacy) (4.4.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.0.0->textacy) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy>=3.0.0->textacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy>=3.0.0->textacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy>=3.0.0->textacy) (2.0.1)
# Building wheels for collected packages: jellyfish
#   Building wheel for jellyfish (setup.py) ... done
#   Created wheel for jellyfish: filename=jellyfish-0.9.0-cp38-cp38-linux_x86_64.whl size=70611 sha256=cd7716cfd487559956816e9b27e716302dbe0dbefaa556b191480dcd200d99e3
#   Stored in directory: /root/.cache/pip/wheels/f1/c7/3c/4c83132de76359e3a429fd09c08995945ca96c5290a41651d3
# Successfully built jellyfish
# Installing collected packages: pyphen, jellyfish, cytoolz, textacy
# Successfully installed cytoolz-0.12.1 jellyfish-0.9.0 pyphen-0.13.2 textacy-0.12.0

# %%
from textacy.extract import subject_verb_object_triples
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp('They are watching a movie')
iterator = subject_verb_object_triples(doc)
for it in iterator:
    print(it)
# Out:
# SVOTriple(subject=[They], verb=[are, watching], object=[movie])

# %% [markdown]
# ## 1.4. Extract SVO Triples

# %%
from tqdm import tqdm

# %%
triples_raw = []

for p in tqdm(phrases):
    iterator = subject_verb_object_triples(nlp(p))
    phrase_triples = []
    for svo in iterator:
        phrase_triples.append(svo)
    triples_raw.append(phrase_triples)
# Out:
# 100%|██████████| 28127/28127 [04:55<00:00, 95.20it/s]

# %% [markdown]
# ## 1.5. Lemmatize & Stem SVO Triples

# %%
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.corpus.reader.wordnet import VERB

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatized_triples = []
lemmatized_stemmed_triples = []

# %%
stemmer = SnowballStemmer('english')

# %%
def lemmatize_stem(text):
    # lemmatize + stem a text
    return stemmer.stem(WordNetLemmatizer().lemmatize(text))

# %%
phrase_counter = 0
found_triples_counter = 0

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
for (phrase, phrase_triples) in zip(phrases, triples_raw):
    print('phrase triples:', phrase_triples)
    if len(phrase) > 0:
        phrase_counter += 1
    if phrase_triples:
        found_triples_counter += 1
        for triple in phrase_triples:
            print('raw triples:', triple)
            # lemmatize
            s = lemmatizer.lemmatize(str(triple[0]))
            o = lemmatizer.lemmatize(str(triple[2]))
            v = lemmatizer.lemmatize(str(triple[1][-1]), VERB)  # take last token in verb expression
            
            # lemmatize & stem
            lss = lemmatize_stem(str(triple[0]))
            lso = lemmatize_stem(str(triple[2]))
            lsv = lemmatize_stem(str(triple[1][-1]))
            
            print('lemmatized: s:', s, ', o:', o, ', v:', v)
            print('lemmatized&stemmed: s:', lss, ', o:', lso, ', v:', lsv)
            
            lemmatized_triples.append([s.lower(), v.lower(), o.lower()])
            lemmatized_stemmed_triples.append([lss.lower(), lsv.lower(), lso.lower()])
    else:
        print('Could not detect triples in phrase:', phrase)
        lemmatized_triples.append([])
        lemmatized_stemmed_triples.append([])
# Out:
# Streaming output truncated to the last 5000 lines.
# phrase triples: [SVOTriple(subject=[Roscoe], verb=[is, greeted], object=[parents, Roscoe, Sr])]
# raw triples: SVOTriple(subject=[Roscoe], verb=[is, greeted], object=[parents, Roscoe, Sr])
# lemmatized: s: [Roscoe] , o: [parents, Roscoe, Sr] , v: greet
# lemmatized&stemmed: s: [roscoe] , o: [parents, roscoe, sr] , v: greet
# phrase triples: []
# Could not detect triples in phrase: (James Earl Jones) and Mama Jenkins (Margaret Avery); his brother, Otis (Michael Clarke Duncan), the town sheriff; Otis' wife, Ruthie (Liz Mikel) and their overgrown kids, Junior (Brandin Jenkins) and Callie (Krystal Marea Braud); and Roscoe's loud, rowdy sister, Betty (Mo'Nique)
# phrase triples: [SVOTriple(subject=[he], verb=[is, escorting], object=[Lucinda])]
# raw triples: SVOTriple(subject=[he], verb=[is, escorting], object=[Lucinda])
# lemmatized: s: [he] , o: [Lucinda] , v: escort
# lemmatized&stemmed: s: [he] , o: [lucinda] , v: escort
# phrase triples: [SVOTriple(subject=[Roscoe], verb=[endures], object=[self, humiliation]), SVOTriple(subject=[he], verb=[insults], object=[them])]
# raw triples: SVOTriple(subject=[Roscoe], verb=[endures], object=[self, humiliation])
# lemmatized: s: [Roscoe] , o: [self, humiliation] , v: endure
# lemmatized&stemmed: s: [roscoe] , o: [self, humiliation] , v: endur
# raw triples: SVOTriple(subject=[he], verb=[insults], object=[them])
# lemmatized: s: [he] , o: [them] , v: insult
# lemmatized&stemmed: s: [he] , o: [them] , v: insult
# phrase triples: [SVOTriple(subject=[he], verb=[holds], object=[grudge]), SVOTriple(subject=[he], verb=[treated], object=[him]), SVOTriple(subject=[he], verb=[would, n't, discipline], object=[him])]
# raw triples: SVOTriple(subject=[he], verb=[holds], object=[grudge])
# lemmatized: s: [he] , o: [grudge] , v: hold
# lemmatized&stemmed: s: [he] , o: [grudge] , v: hold
# raw triples: SVOTriple(subject=[he], verb=[treated], object=[him])
# lemmatized: s: [he] , o: [him] , v: treat
# lemmatized&stemmed: s: [he] , o: [him] , v: treat
# raw triples: SVOTriple(subject=[he], verb=[would, n't, discipline], object=[him])
# lemmatized: s: [he] , o: [him] , v: discipline
# lemmatized&stemmed: s: [he] , o: [him] , v: disciplin
# phrase triples: []
# Could not detect triples in phrase: Roscoe Sr
# phrase triples: []
# Could not detect triples in phrase: resents his son for changing his name and distancing himself from his family
# phrase triples: []
# Could not detect triples in phrase: Meanwhile, Bianca doesn't fit in well with the family and Roscoe and Lucinda get reacquainted
# phrase triples: []
# Could not detect triples in phrase: On the day of the Jenkins' anniversary, the whole family gathers for the traditional Jenkins-family obstacle course
# phrase triples: [SVOTriple(subject=[he], verb=[challenges], object=[him]), SVOTriple(subject=[two], verb=[become], object=[him])]
# raw triples: SVOTriple(subject=[he], verb=[challenges], object=[him])
# lemmatized: s: [he] , o: [him] , v: challenge
# lemmatized&stemmed: s: [he] , o: [him] , v: challeng
# raw triples: SVOTriple(subject=[two], verb=[become], object=[him])
# lemmatized: s: [two] , o: [him] , v: become
# lemmatized&stemmed: s: [two] , o: [him] , v: becom
# phrase triples: [SVOTriple(subject=[Roscoe, Clyde], verb=[make], object=[way])]
# raw triples: SVOTriple(subject=[Roscoe, Clyde], verb=[make], object=[way])
# lemmatized: s: [Roscoe, Clyde] , o: [way] , v: make
# lemmatized&stemmed: s: [roscoe, clyde] , o: [way] , v: make
# phrase triples: [SVOTriple(subject=[Roscoe], verb=[begins], object=[to, help, his, son, over]), SVOTriple(subject=[Bianca], verb=[tells], object=[him]), SVOTriple(subject=[he], verb=[does], object=[to, help, his, son, over, him])]
# raw triples: SVOTriple(subject=[Roscoe], verb=[begins], object=[to, help, his, son, over])
# lemmatized: s: [Roscoe] , o: [to, help, his, son, over] , v: begin
# lemmatized&stemmed: s: [roscoe] , o: [to, help, his, son, over] , v: begin
# raw triples: SVOTriple(subject=[Bianca], verb=[tells], object=[him])
# lemmatized: s: [Bianca] , o: [him] , v: tell
# lemmatized&stemmed: s: [bianca] , o: [him] , v: tell
# raw triples: SVOTriple(subject=[he], verb=[does], object=[to, help, his, son, over, him])
# lemmatized: s: [he] , o: [to, help, his, son, over, him] , v: do
# lemmatized&stemmed: s: [he] , o: [to, help, his, son, over, him] , v: doe
# phrase triples: []
# Could not detect triples in phrase: Roscoe and Clyde race to the finish line, and Roscoe wins
# phrase triples: [SVOTriple(subject=[everyone], verb=[reminding], object=[them])]
# raw triples: SVOTriple(subject=[everyone], verb=[reminding], object=[them])
# lemmatized: s: [everyone] , o: [them] , v: remind
# lemmatized&stemmed: s: [everyone] , o: [them] , v: remind
# phrase triples: [SVOTriple(subject=[Jamaal], verb=[refuses], object=[to, go, near, his, father])]
# raw triples: SVOTriple(subject=[Jamaal], verb=[refuses], object=[to, go, near, his, father])
# lemmatized: s: [Jamaal] , o: [to, go, near, his, father] , v: refuse
# lemmatized&stemmed: s: [jamaal] , o: [to, go, near, his, father] , v: refus
# phrase triples: []
# Could not detect triples in phrase: chastises his son
# phrase triples: [SVOTriple(subject=[he], verb=[lost], object=[father]), SVOTriple(subject=[he], verb=[favored], object=[Clyde]), SVOTriple(subject=[he], verb=[chastises], object=[him])]
# raw triples: SVOTriple(subject=[he], verb=[lost], object=[father])
# lemmatized: s: [he] , o: [father] , v: lose
# lemmatized&stemmed: s: [he] , o: [father] , v: lost
# raw triples: SVOTriple(subject=[he], verb=[favored], object=[Clyde])
# lemmatized: s: [he] , o: [Clyde] , v: favor
# lemmatized&stemmed: s: [he] , o: [clyde] , v: favor
# raw triples: SVOTriple(subject=[he], verb=[chastises], object=[him])
# lemmatized: s: [he] , o: [him] , v: chastise
# lemmatized&stemmed: s: [he] , o: [him] , v: chastis
# phrase triples: []
# Could not detect triples in phrase: Stunned and distraught by this admission, Roscoe Sr
# phrase triples: []
# Could not detect triples in phrase: walks away; feeling hurt
# phrase triples: [SVOTriple(subject=[he], verb=[never, tried], object=[to, take, his, place])]
# raw triples: SVOTriple(subject=[he], verb=[never, tried], object=[to, take, his, place])
# lemmatized: s: [he] , o: [to, take, his, place] , v: try
# lemmatized&stemmed: s: [he] , o: [to, take, his, place] , v: tri
# phrase triples: [SVOTriple(subject=[He], verb=[tries], object=[to, shake, Roscoe, 's, hand, to, make, amends]), SVOTriple(subject=[Bianca], verb=[tells], object=[him]), SVOTriple(subject=[Roscoe], verb=[decides], object=[he]), SVOTriple(subject=[Jamaal], verb=[should, start], object=[to, shake, Roscoe, 's, hand, to, make, amends, him, he])]
# raw triples: SVOTriple(subject=[He], verb=[tries], object=[to, shake, Roscoe, 's, hand, to, make, amends])
# lemmatized: s: [He] , o: [to, shake, Roscoe, 's, hand, to, make, amends] , v: try
# lemmatized&stemmed: s: [he] , o: [to, shake, roscoe, 's, hand, to, make, amends] , v: tri
# raw triples: SVOTriple(subject=[Bianca], verb=[tells], object=[him])
# lemmatized: s: [Bianca] , o: [him] , v: tell
# lemmatized&stemmed: s: [bianca] , o: [him] , v: tell
# raw triples: SVOTriple(subject=[Roscoe], verb=[decides], object=[he])
# lemmatized: s: [Roscoe] , o: [he] , v: decide
# lemmatized&stemmed: s: [roscoe] , o: [he] , v: decid
# raw triples: SVOTriple(subject=[Jamaal], verb=[should, start], object=[to, shake, Roscoe, 's, hand, to, make, amends, him, he])
# lemmatized: s: [Jamaal] , o: [to, shake, Roscoe, 's, hand, to, make, amends, him, he] , v: start
# lemmatized&stemmed: s: [jamaal] , o: [to, shake, roscoe, 's, hand, to, make, amends, him, he] , v: start
# phrase triples: [SVOTriple(subject=[mother], verb=[reminds], object=[him]), SVOTriple(subject=[family], verb=[loves], object=[him])]
# raw triples: SVOTriple(subject=[mother], verb=[reminds], object=[him])
# lemmatized: s: [mother] , o: [him] , v: remind
# lemmatized&stemmed: s: [mother] , o: [him] , v: remind
# raw triples: SVOTriple(subject=[family], verb=[loves], object=[him])
# lemmatized: s: [family] , o: [him] , v: love
# lemmatized&stemmed: s: [family] , o: [him] , v: love
# phrase triples: [SVOTriple(subject=[Bianca], verb=[proposes], object=[not, inviting, the, family, to, their, wedding])]
# raw triples: SVOTriple(subject=[Bianca], verb=[proposes], object=[not, inviting, the, family, to, their, wedding])
# lemmatized: s: [Bianca] , o: [not, inviting, the, family, to, their, wedding] , v: propose
# lemmatized&stemmed: s: [bianca] , o: [not, inviting, the, family, to, their, wedding] , v: propos
# phrase triples: [SVOTriple(subject=[Roscoe], verb=[seems], object=[to, agree]), SVOTriple(subject=[which], verb=[upsets], object=[Jamaal]), SVOTriple(subject=[him], verb=[to, get], object=[Team]), SVOTriple(subject=[he], verb=[declares], object=[himself, Jenkins])]
# raw triples: SVOTriple(subject=[Roscoe], verb=[seems], object=[to, agree])
# lemmatized: s: [Roscoe] , o: [to, agree] , v: seem
# lemmatized&stemmed: s: [roscoe] , o: [to, agree] , v: seem
# raw triples: SVOTriple(subject=[which], verb=[upsets], object=[Jamaal])
# lemmatized: s: [which] , o: [Jamaal] , v: upset
# lemmatized&stemmed: s: [which] , o: [jamaal] , v: upset
# raw triples: SVOTriple(subject=[him], verb=[to, get], object=[Team])
# lemmatized: s: [him] , o: [Team] , v: get
# lemmatized&stemmed: s: [him] , o: [team] , v: get
# raw triples: SVOTriple(subject=[he], verb=[declares], object=[himself, Jenkins])
# lemmatized: s: [he] , o: [himself, Jenkins] , v: declare
# lemmatized&stemmed: s: [he] , o: [himself, jenkins] , v: declar
# phrase triples: [SVOTriple(subject=[Bianca], verb=[continues], object=[to, say, mean, things, about, the, Jenkins, clan, and, Roscoe, pretends, to, agree, with, her]), SVOTriple(subject=[he], verb=[thanks], object=[her]), SVOTriple(subject=[him], verb=[see], object=[colors]), SVOTriple(subject=[he], verb=[dumps], object=[her])]
# raw triples: SVOTriple(subject=[Bianca], verb=[continues], object=[to, say, mean, things, about, the, Jenkins, clan, and, Roscoe, pretends, to, agree, with, her])
# lemmatized: s: [Bianca] , o: [to, say, mean, things, about, the, Jenkins, clan, and, Roscoe, pretends, to, agree, with, her] , v: continue
# lemmatized&stemmed: s: [bianca] , o: [to, say, mean, things, about, the, jenkins, clan, and, roscoe, pretends, to, agree, with, her] , v: continu
# raw triples: SVOTriple(subject=[he], verb=[thanks], object=[her])
# lemmatized: s: [he] , o: [her] , v: thank
# lemmatized&stemmed: s: [he] , o: [her] , v: thank
# raw triples: SVOTriple(subject=[him], verb=[see], object=[colors])
# lemmatized: s: [him] , o: [colors] , v: see
# lemmatized&stemmed: s: [him] , o: [colors] , v: see
# raw triples: SVOTriple(subject=[he], verb=[dumps], object=[her])
# lemmatized: s: [he] , o: [her] , v: dump
# lemmatized&stemmed: s: [he] , o: [her] , v: dump
# phrase triples: []
# Could not detect triples in phrase: Angrily, feeling humiliated by Roscoe and Jamaal, she gets out of the car
# phrase triples: [SVOTriple(subject=[he], verb=[pulls], object=[rope])]
# raw triples: SVOTriple(subject=[he], verb=[pulls], object=[rope])
# lemmatized: s: [he] , o: [rope] , v: pull
# lemmatized&stemmed: s: [he] , o: [rope] , v: pull
# phrase triples: [SVOTriple(subject=[who], verb=[had, turned], object=[Jenkins, clan]), SVOTriple(subject=[who], verb=[joined], object=[Jenkins, clan])]
# raw triples: SVOTriple(subject=[who], verb=[had, turned], object=[Jenkins, clan])
# lemmatized: s: [who] , o: [Jenkins, clan] , v: turn
# lemmatized&stemmed: s: [who] , o: [jenkins, clan] , v: turn
# raw triples: SVOTriple(subject=[who], verb=[joined], object=[Jenkins, clan])
# lemmatized: s: [who] , o: [Jenkins, clan] , v: join
# lemmatized&stemmed: s: [who] , o: [jenkins, clan] , v: join
# phrase triples: [SVOTriple(subject=[he], verb=[cared], object=[lot])]
# raw triples: SVOTriple(subject=[he], verb=[cared], object=[lot])
# lemmatized: s: [he] , o: [lot] , v: care
# lemmatized&stemmed: s: [he] , o: [lot] , v: care
# phrase triples: []
# Could not detect triples in phrase: Roscoe suddenly appears, apologizes to his family, and congratulates his parents
# phrase triples: [SVOTriple(subject=[He, father], verb=[make], object=[amends]), SVOTriple(subject=[Roscoe], verb=[asks], object=[Lucinda])]
# raw triples: SVOTriple(subject=[He, father], verb=[make], object=[amends])
# lemmatized: s: [He, father] , o: [amends] , v: make
# lemmatized&stemmed: s: [he, father] , o: [amends] , v: make
# raw triples: SVOTriple(subject=[Roscoe], verb=[asks], object=[Lucinda])
# lemmatized: s: [Roscoe] , o: [Lucinda] , v: ask
# lemmatized&stemmed: s: [roscoe] , o: [lucinda] , v: ask
# phrase triples: [SVOTriple(subject=[family], verb=[watches], object=[it]), SVOTriple(subject=[Roscoe, Lucinda], verb=[make], object=[love]), SVOTriple(subject=[surprise], verb=[having, had], object=[intercourse])]
# raw triples: SVOTriple(subject=[family], verb=[watches], object=[it])
# lemmatized: s: [family] , o: [it] , v: watch
# lemmatized&stemmed: s: [family] , o: [it] , v: watch
# raw triples: SVOTriple(subject=[Roscoe, Lucinda], verb=[make], object=[love])
# lemmatized: s: [Roscoe, Lucinda] , o: [love] , v: make
# lemmatized&stemmed: s: [roscoe, lucinda] , o: [love] , v: make
# raw triples: SVOTriple(subject=[surprise], verb=[having, had], object=[intercourse])
# lemmatized: s: [surprise] , o: [intercourse] , v: have
# lemmatized&stemmed: s: [surprise] , o: [intercourse] , v: had
# phrase triples: [SVOTriple(subject=[Roscoe], verb=[is, seen], object=[interviewing, his, family, on, his, show])]
# raw triples: SVOTriple(subject=[Roscoe], verb=[is, seen], object=[interviewing, his, family, on, his, show])
# lemmatized: s: [Roscoe] , o: [interviewing, his, family, on, his, show] , v: see
# lemmatized&stemmed: s: [roscoe] , o: [interviewing, his, family, on, his, show] , v: seen
# phrase triples: [SVOTriple(subject=[trader, Joy, Ellis, McNally], verb=[is, dumped], object=[fiancé])]
# raw triples: SVOTriple(subject=[trader, Joy, Ellis, McNally], verb=[is, dumped], object=[fiancé])
# lemmatized: s: [trader, Joy, Ellis, McNally] , o: [fiancé] , v: dump
# lemmatized&stemmed: s: [trader, joy, ellis, mcnally] , o: [fiancé] , v: dump
# phrase triples: [SVOTriple(subject=[carpenter, Jack, Fuller], verb=[is, fired], object=[father])]
# raw triples: SVOTriple(subject=[carpenter, Jack, Fuller], verb=[is, fired], object=[father])
# lemmatized: s: [carpenter, Jack, Fuller] , o: [father] , v: fire
# lemmatized&stemmed: s: [carpenter, jack, fuller] , o: [father] , v: fire
# phrase triples: [SVOTriple(subject=[Both], verb=[become], object=[trip]), SVOTriple(subject=[Both], verb=[take], object=[trip])]
# raw triples: SVOTriple(subject=[Both], verb=[become], object=[trip])
# lemmatized: s: [Both] , o: [trip] , v: become
# lemmatized&stemmed: s: [both] , o: [trip] , v: becom
# raw triples: SVOTriple(subject=[Both], verb=[take], object=[trip])
# lemmatized: s: [Both] , o: [trip] , v: take
# lemmatized&stemmed: s: [both] , o: [trip] , v: take
# phrase triples: [SVOTriple(subject=[they], verb=[are, given], object=[hotel, room])]
# raw triples: SVOTriple(subject=[they], verb=[are, given], object=[hotel, room])
# lemmatized: s: [they] , o: [hotel, room] , v: give
# lemmatized&stemmed: s: [they] , o: [hotel, room] , v: given
# phrase triples: []
# Could not detect triples in phrase: After clearing up the misunderstanding and receiving upgraded rooms and coupons to various clubs, they party and drink together and end up getting married
# phrase triples: []
# Could not detect triples in phrase: The next morning, they realize it was a mistake and decide to divorce
# phrase triples: [SVOTriple(subject=[Jack], verb=[uses], object=[quarter]), SVOTriple(subject=[Joy], verb=[gives], object=[him])]
# raw triples: SVOTriple(subject=[Jack], verb=[uses], object=[quarter])
# lemmatized: s: [Jack] , o: [quarter] , v: use
# lemmatized&stemmed: s: [jack] , o: [quarter] , v: us
# raw triples: SVOTriple(subject=[Joy], verb=[gives], object=[him])
# lemmatized: s: [Joy] , o: [him] , v: give
# lemmatized&stemmed: s: [joy] , o: [him] , v: give
# phrase triples: [SVOTriple(subject=[He], verb=[hits], object=[dollar, jackpot]), SVOTriple(subject=[Joy], verb=[reminds], object=[Jack])]
# raw triples: SVOTriple(subject=[He], verb=[hits], object=[dollar, jackpot])
# lemmatized: s: [He] , o: [dollar, jackpot] , v: hit
# lemmatized&stemmed: s: [he] , o: [dollar, jackpot] , v: hit
# raw triples: SVOTriple(subject=[Joy], verb=[reminds], object=[Jack])
# lemmatized: s: [Joy] , o: [Jack] , v: remind
# lemmatized&stemmed: s: [joy] , o: [jack] , v: remind
# phrase triples: [SVOTriple(subject=[they], verb=[attempt], object=[where, to, divorce])]
# raw triples: SVOTriple(subject=[they], verb=[attempt], object=[where, to, divorce])
# lemmatized: s: [they] , o: [where, to, divorce] , v: attempt
# lemmatized&stemmed: s: [they] , o: [where, to, divorce] , v: attempt
# phrase triples: [SVOTriple(subject=[they], verb=[attempt], object=[to, co, -, exist, for, six, months])]
# raw triples: SVOTriple(subject=[they], verb=[attempt], object=[to, co, -, exist, for, six, months])
# lemmatized: s: [they] , o: [to, co, -, exist, for, six, months] , v: attempt
# lemmatized&stemmed: s: [they] , o: [to, co, -, exist, for, six, months] , v: attempt
# phrase triples: []
# Could not detect triples in phrase: Twitchell, a marriage counselor
# phrase triples: [SVOTriple(subject=[they], verb=[work], object=[to, divorce, after, six, months]), SVOTriple(subject=[they], verb=[want], object=[to, divorce, after, six, months]), SVOTriple(subject=[each], verb=[will, be, permitted], object=[to, keep, half, the, winnings])]
# raw triples: SVOTriple(subject=[they], verb=[work], object=[to, divorce, after, six, months])
# lemmatized: s: [they] , o: [to, divorce, after, six, months] , v: work
# lemmatized&stemmed: s: [they] , o: [to, divorce, after, six, months] , v: work
# raw triples: SVOTriple(subject=[they], verb=[want], object=[to, divorce, after, six, months])
# lemmatized: s: [they] , o: [to, divorce, after, six, months] , v: want
# lemmatized&stemmed: s: [they] , o: [to, divorce, after, six, months] , v: want
# raw triples: SVOTriple(subject=[each], verb=[will, be, permitted], object=[to, keep, half, the, winnings])
# lemmatized: s: [each] , o: [to, keep, half, the, winnings] , v: permit
# lemmatized&stemmed: s: [each] , o: [to, keep, half, the, winnings] , v: permit
# phrase triples: [SVOTriple(subject=[money], verb=[will, be, tied], object=[judge])]
# raw triples: SVOTriple(subject=[money], verb=[will, be, tied], object=[judge])
# lemmatized: s: [money] , o: [judge] , v: tie
# lemmatized&stemmed: s: [money] , o: [judge] , v: tie
# phrase triples: [SVOTriple(subject=[newlyweds], verb=[devise], object=[schemes]), SVOTriple(subject=[Jack], verb=[telling], object=[Joy]), SVOTriple(subject=[Joy], verb=[inviting], object=[girls])]
# raw triples: SVOTriple(subject=[newlyweds], verb=[devise], object=[schemes])
# lemmatized: s: [newlyweds] , o: [schemes] , v: devise
# lemmatized&stemmed: s: [newlyweds] , o: [schemes] , v: devis
# raw triples: SVOTriple(subject=[Jack], verb=[telling], object=[Joy])
# lemmatized: s: [Jack] , o: [Joy] , v: tell
# lemmatized&stemmed: s: [jack] , o: [joy] , v: tell
# raw triples: SVOTriple(subject=[Joy], verb=[inviting], object=[girls])
# lemmatized: s: [Joy] , o: [girls] , v: invite
# lemmatized&stemmed: s: [joy] , o: [girls] , v: invit
# phrase triples: [SVOTriple(subject=[Jack], verb=[gives], object=[ex, -, fiancé])]
# raw triples: SVOTriple(subject=[Jack], verb=[gives], object=[ex, -, fiancé])
# lemmatized: s: [Jack] , o: [ex, -, fiancé] , v: give
# lemmatized&stemmed: s: [jack] , o: [ex, -, fiancé] , v: give
# phrase triples: [SVOTriple(subject=[themselves], verb=[developing], object=[attraction]), SVOTriple(subject=[being, with, each, other], verb=[has, brought], object=[best])]
# raw triples: SVOTriple(subject=[themselves], verb=[developing], object=[attraction])
# lemmatized: s: [themselves] , o: [attraction] , v: develop
# lemmatized&stemmed: s: [themselves] , o: [attraction] , v: develop
# raw triples: SVOTriple(subject=[being, with, each, other], verb=[has, brought], object=[best])
# lemmatized: s: [being, with, each, other] , o: [best] , v: bring
# lemmatized&stemmed: s: [being, with, each, other] , o: [best] , v: brought
# phrase triples: []
# Could not detect triples in phrase: After they get back from the retreat, it's time for the judge to decide what happens to the money
# phrase triples: [SVOTriple(subject=[Joy], verb=[sees], object=[ex, Mason]), SVOTriple(subject=[he], verb=[tells], object=[her]), SVOTriple(subject=[he], verb=[wants], object=[her])]
# raw triples: SVOTriple(subject=[Joy], verb=[sees], object=[ex, Mason])
# lemmatized: s: [Joy] , o: [ex, Mason] , v: see
# lemmatized&stemmed: s: [joy] , o: [ex, mason] , v: see
# raw triples: SVOTriple(subject=[he], verb=[tells], object=[her])
# lemmatized: s: [he] , o: [her] , v: tell
# lemmatized&stemmed: s: [he] , o: [her] , v: tell
# raw triples: SVOTriple(subject=[he], verb=[wants], object=[her])
# lemmatized: s: [he] , o: [her] , v: want
# lemmatized&stemmed: s: [he] , o: [her] , v: want
# phrase triples: [SVOTriple(subject=[He], verb=[gives], object=[engagement, ring]), SVOTriple(subject=[He], verb=[tells], object=[her])]
# raw triples: SVOTriple(subject=[He], verb=[gives], object=[engagement, ring])
# lemmatized: s: [He] , o: [engagement, ring] , v: give
# lemmatized&stemmed: s: [he] , o: [engagement, ring] , v: give
# raw triples: SVOTriple(subject=[He], verb=[tells], object=[her])
# lemmatized: s: [He] , o: [her] , v: tell
# lemmatized&stemmed: s: [he] , o: [her] , v: tell
# phrase triples: [SVOTriple(subject=[Jack], verb=[set], object=[her]), SVOTriple(subject=[Jack], verb=[keep], object=[money])]
# raw triples: SVOTriple(subject=[Jack], verb=[set], object=[her])
# lemmatized: s: [Jack] , o: [her] , v: set
# lemmatized&stemmed: s: [jack] , o: [her] , v: set
# raw triples: SVOTriple(subject=[Jack], verb=[keep], object=[money])
# lemmatized: s: [Jack] , o: [money] , v: keep
# lemmatized&stemmed: s: [jack] , o: [money] , v: keep
# phrase triples: []
# Could not detect triples in phrase: Joy walks away from Mason and goes to the hearing
# phrase triples: [SVOTriple(subject=[couple], verb=[tried], object=[to, work, on, their, marriage])]
# raw triples: SVOTriple(subject=[couple], verb=[tried], object=[to, work, on, their, marriage])
# lemmatized: s: [couple] , o: [to, work, on, their, marriage] , v: try
# lemmatized&stemmed: s: [couple] , o: [to, work, on, their, marriage] , v: tri
# phrase triples: [SVOTriple(subject=[they], verb=[will, split], object=[1])]
# raw triples: SVOTriple(subject=[they], verb=[will, split], object=[1])
# lemmatized: s: [they] , o: [1] , v: split
# lemmatized&stemmed: s: [they] , o: [1] , v: split
# phrase triples: [SVOTriple(subject=[dollars, Joy], verb=[ran], object=[bills])]
# raw triples: SVOTriple(subject=[dollars, Joy], verb=[ran], object=[bills])
# lemmatized: s: [dollars, Joy] , o: [bills] , v: run
# lemmatized&stemmed: s: [dollars, joy] , o: [bills] , v: ran
# phrase triples: [SVOTriple(subject=[Joy], verb=[tells], object=[judge]), SVOTriple(subject=[she], verb=[does, n't, want], object=[money]), SVOTriple(subject=[she], verb=[gives], object=[engagement, ring]), SVOTriple(subject=[she], verb=[does, n't, want], object=[anything])]
# raw triples: SVOTriple(subject=[Joy], verb=[tells], object=[judge])
# lemmatized: s: [Joy] , o: [judge] , v: tell
# lemmatized&stemmed: s: [joy] , o: [judge] , v: tell
# raw triples: SVOTriple(subject=[she], verb=[does, n't, want], object=[money])
# lemmatized: s: [she] , o: [money] , v: want
# lemmatized&stemmed: s: [she] , o: [money] , v: want
# raw triples: SVOTriple(subject=[she], verb=[gives], object=[engagement, ring])
# lemmatized: s: [she] , o: [engagement, ring] , v: give
# lemmatized&stemmed: s: [she] , o: [engagement, ring] , v: give
# raw triples: SVOTriple(subject=[she], verb=[does, n't, want], object=[anything])
# lemmatized: s: [she] , o: [anything] , v: want
# lemmatized&stemmed: s: [she] , o: [anything] , v: want
# phrase triples: []
# Could not detect triples in phrase: Jack realizes she knows that he talked to Mason
# phrase triples: [SVOTriple(subject=[Joy], verb=[gets], object=[promotion]), SVOTriple(subject=[Joy], verb=[tells], object=[boss])]
# raw triples: SVOTriple(subject=[Joy], verb=[gets], object=[promotion])
# lemmatized: s: [Joy] , o: [promotion] , v: get
# lemmatized&stemmed: s: [joy] , o: [promotion] , v: get
# raw triples: SVOTriple(subject=[Joy], verb=[tells], object=[boss])
# lemmatized: s: [Joy] , o: [boss] , v: tell
# lemmatized&stemmed: s: [joy] , o: [boss] , v: tell
# phrase triples: [SVOTriple(subject=[Jack], verb=[talks], object=[him]), SVOTriple(subject=[they], verb=[tell], object=[him])]
# raw triples: SVOTriple(subject=[Jack], verb=[talks], object=[him])
# lemmatized: s: [Jack] , o: [him] , v: talk
# lemmatized&stemmed: s: [jack] , o: [him] , v: talk
# raw triples: SVOTriple(subject=[they], verb=[tell], object=[him])
# lemmatized: s: [they] , o: [him] , v: tell
# lemmatized&stemmed: s: [they] , o: [him] , v: tell
# phrase triples: [SVOTriple(subject=[he], verb=[goes], object=[to, find, her])]
# raw triples: SVOTriple(subject=[he], verb=[goes], object=[to, find, her])
# lemmatized: s: [he] , o: [to, find, her] , v: go
# lemmatized&stemmed: s: [he] , o: [to, find, her] , v: go
# phrase triples: [SVOTriple(subject=[Tipper], verb=[tells], object=[Jack]), SVOTriple(subject=[she], verb=[quit], object=[job]), SVOTriple(subject=[nobody], verb=[knows], object=[job])]
# raw triples: SVOTriple(subject=[Tipper], verb=[tells], object=[Jack])
# lemmatized: s: [Tipper] , o: [Jack] , v: tell
# lemmatized&stemmed: s: [tipper] , o: [jack] , v: tell
# raw triples: SVOTriple(subject=[she], verb=[quit], object=[job])
# lemmatized: s: [she] , o: [job] , v: quit
# lemmatized&stemmed: s: [she] , o: [job] , v: quit
# raw triples: SVOTriple(subject=[nobody], verb=[knows], object=[job])
# lemmatized: s: [nobody] , o: [job] , v: know
# lemmatized&stemmed: s: [nobody] , o: [job] , v: know
# phrase triples: [SVOTriple(subject=[He], verb=[has], object=[suspicion]), SVOTriple(subject=[she], verb=[told], object=[him, place])]
# raw triples: SVOTriple(subject=[He], verb=[has], object=[suspicion])
# lemmatized: s: [He] , o: [suspicion] , v: have
# lemmatized&stemmed: s: [he] , o: [suspicion] , v: ha
# raw triples: SVOTriple(subject=[she], verb=[told], object=[him, place])
# lemmatized: s: [she] , o: [him, place] , v: tell
# lemmatized&stemmed: s: [she] , o: [him, place] , v: told
# phrase triples: [SVOTriple(subject=[Jack], verb=[asks], object=[her]), SVOTriple(subject=[she], verb=[says], object=[her])]
# raw triples: SVOTriple(subject=[Jack], verb=[asks], object=[her])
# lemmatized: s: [Jack] , o: [her] , v: ask
# lemmatized&stemmed: s: [jack] , o: [her] , v: ask
# raw triples: SVOTriple(subject=[she], verb=[says], object=[her])
# lemmatized: s: [she] , o: [her] , v: say
# lemmatized&stemmed: s: [she] , o: [her] , v: say
# phrase triples: [SVOTriple(subject=[she], verb=[quit], object=[job]), SVOTriple(subject=[she], verb=[has], object=[idea]), SVOTriple(subject=[she], verb=['s, going], object=[what, to, do])]
# raw triples: SVOTriple(subject=[she], verb=[quit], object=[job])
# lemmatized: s: [she] , o: [job] , v: quit
# lemmatized&stemmed: s: [she] , o: [job] , v: quit
# raw triples: SVOTriple(subject=[she], verb=[has], object=[idea])
# lemmatized: s: [she] , o: [idea] , v: have
# lemmatized&stemmed: s: [she] , o: [idea] , v: ha
# raw triples: SVOTriple(subject=[she], verb=['s, going], object=[what, to, do])
# lemmatized: s: [she] , o: [what, to, do] , v: go
# lemmatized&stemmed: s: [she] , o: [what, to, do] , v: go
# phrase triples: [SVOTriple(subject=[Jack], verb=[reminds], object=[her]), SVOTriple(subject=[they], verb=[have], object=[lot])]
# raw triples: SVOTriple(subject=[Jack], verb=[reminds], object=[her])
# lemmatized: s: [Jack] , o: [her] , v: remind
# lemmatized&stemmed: s: [jack] , o: [her] , v: remind
# raw triples: SVOTriple(subject=[they], verb=[have], object=[lot])
# lemmatized: s: [they] , o: [lot] , v: have
# lemmatized&stemmed: s: [they] , o: [lot] , v: have
# phrase triples: [SVOTriple(subject=[they], verb=[hit], object=[jackpot])]
# raw triples: SVOTriple(subject=[they], verb=[hit], object=[jackpot])
# lemmatized: s: [they] , o: [jackpot] , v: hit
# lemmatized&stemmed: s: [they] , o: [jackpot] , v: hit
# phrase triples: [SVOTriple(subject=[we], verb=[see], object=[Tipper, Hater]), SVOTriple(subject=[Jack, Joy], verb=[get], object=[Tipper, Hater])]
# raw triples: SVOTriple(subject=[we], verb=[see], object=[Tipper, Hater])
# lemmatized: s: [we] , o: [Tipper, Hater] , v: see
# lemmatized&stemmed: s: [we] , o: [tipper, hater] , v: see
# raw triples: SVOTriple(subject=[Jack, Joy], verb=[get], object=[Tipper, Hater])
# lemmatized: s: [Jack, Joy] , o: [Tipper, Hater] , v: get
# lemmatized&stemmed: s: [jack, joy] , o: [tipper, hater] , v: get
# phrase triples: [SVOTriple(subject=[Tipper, Hater], verb=[enact], object=[plan])]
# raw triples: SVOTriple(subject=[Tipper, Hater], verb=[enact], object=[plan])
# lemmatized: s: [Tipper, Hater] , o: [plan] , v: enact
# lemmatized&stemmed: s: [tipper, hater] , o: [plan] , v: enact
# phrase triples: [SVOTriple(subject=[Tipper], verb=[slugs], object=[him])]
# raw triples: SVOTriple(subject=[Tipper], verb=[slugs], object=[him])
# lemmatized: s: [Tipper] , o: [him] , v: slug
# lemmatized&stemmed: s: [tipper] , o: [him] , v: slug
# phrase triples: []
# Could not detect triples in phrase: He moans in agony and drops to his knees asking "Why?", and she responds emphatically "You know why!", and Tipper leaves with Hater
# phrase triples: [SVOTriple(subject=[Dave], verb=[is, telling], object=[Hater]), SVOTriple(subject=[Hater], verb=[wants], object=[to, associate, with, Dave]), SVOTriple(subject=[that], verb=[held], object=[two])]
# raw triples: SVOTriple(subject=[Dave], verb=[is, telling], object=[Hater])
# lemmatized: s: [Dave] , o: [Hater] , v: tell
# lemmatized&stemmed: s: [dave] , o: [hater] , v: tell
# raw triples: SVOTriple(subject=[Hater], verb=[wants], object=[to, associate, with, Dave])
# lemmatized: s: [Hater] , o: [to, associate, with, Dave] , v: want
# lemmatized&stemmed: s: [hater] , o: [to, associate, with, dave] , v: want
# raw triples: SVOTriple(subject=[that], verb=[held], object=[two])
# lemmatized: s: [that] , o: [two] , v: hold
# lemmatized&stemmed: s: [that] , o: [two] , v: held
# phrase triples: []
# Could not detect triples in phrase: With that, Hater simply leaves
# phrase triples: [SVOTriple(subject=[Dave], verb=[asks], object=[guy]), SVOTriple(subject=[he], verb=[likes], object=[to, party])]
# raw triples: SVOTriple(subject=[Dave], verb=[asks], object=[guy])
# lemmatized: s: [Dave] , o: [guy] , v: ask
# lemmatized&stemmed: s: [dave] , o: [guy] , v: ask
# raw triples: SVOTriple(subject=[he], verb=[likes], object=[to, party])
# lemmatized: s: [he] , o: [to, party] , v: like
# lemmatized&stemmed: s: [he] , o: [to, party] , v: like
# phrase triples: [SVOTriple(subject=[Ben], verb=[is, suffering], object=[number])]
# raw triples: SVOTriple(subject=[Ben], verb=[is, suffering], object=[number])
# lemmatized: s: [Ben] , o: [number] , v: suffer
# lemmatized&stemmed: s: [ben] , o: [number] , v: suffer
# phrase triples: [SVOTriple(subject=[film], verb=[has], object=[test, screening]), SVOTriple(subject=[which], verb=[features], object=[murder]), SVOTriple(subject=[who], verb=[plays], object=[himself])]
# raw triples: SVOTriple(subject=[film], verb=[has], object=[test, screening])
# lemmatized: s: [film] , o: [test, screening] , v: have
# lemmatized&stemmed: s: [film] , o: [test, screening] , v: ha
# raw triples: SVOTriple(subject=[which], verb=[features], object=[murder])
# lemmatized: s: [which] , o: [murder] , v: feature
# lemmatized&stemmed: s: [which] , o: [murder] , v: featur
# raw triples: SVOTriple(subject=[who], verb=[plays], object=[himself])
# lemmatized: s: [who] , o: [himself] , v: play
# lemmatized&stemmed: s: [who] , o: [himself] , v: play
# phrase triples: [SVOTriple(subject=[Ben, director], verb=[plead], object=[case])]
# raw triples: SVOTriple(subject=[Ben, director], verb=[plead], object=[case])
# lemmatized: s: [Ben, director] , o: [case] , v: plead
# lemmatized&stemmed: s: [ben, director] , o: [case] , v: plead
# phrase triples: [SVOTriple(subject=[She], verb=[accuses], object=[Ben]), SVOTriple(subject=[he], verb=[could, use], object=[it])]
# raw triples: SVOTriple(subject=[She], verb=[accuses], object=[Ben])
# lemmatized: s: [She] , o: [Ben] , v: accuse
# lemmatized&stemmed: s: [she] , o: [ben] , v: accus
# raw triples: SVOTriple(subject=[he], verb=[could, use], object=[it])
# lemmatized: s: [he] , o: [it] , v: use
# lemmatized&stemmed: s: [he] , o: [it] , v: use
# phrase triples: [SVOTriple(subject=[Lou], verb=[threatens], object=[to, pull, Ben, 's, movie, from, Cannes, and, take, over, editing])]
# raw triples: SVOTriple(subject=[Lou], verb=[threatens], object=[to, pull, Ben, 's, movie, from, Cannes, and, take, over, editing])
# lemmatized: s: [Lou] , o: [to, pull, Ben, 's, movie, from, Cannes, and, take, over, editing] , v: threaten
# lemmatized&stemmed: s: [lou] , o: [to, pull, ben, 's, movie, from, cannes, and, take, over, editing] , v: threaten
# phrase triples: []
# Could not detect triples in phrase: Jeremy adamantly refuses, throwing a tantrum
# phrase triples: [SVOTriple(subject=[he], verb=[is, having], object=[trouble])]
# raw triples: SVOTriple(subject=[he], verb=[is, having], object=[trouble])
# lemmatized: s: [he] , o: [trouble] , v: have
# lemmatized&stemmed: s: [he] , o: [trouble] , v: have
# phrase triples: [SVOTriple(subject=[wife], verb=[is, having], object=[affair]), SVOTriple(subject=[Ben], verb=[has, worked], object=[who])]
# raw triples: SVOTriple(subject=[wife], verb=[is, having], object=[affair])
# lemmatized: s: [wife] , o: [affair] , v: have
# lemmatized&stemmed: s: [wife] , o: [affair] , v: have
# raw triples: SVOTriple(subject=[Ben], verb=[has, worked], object=[who])
# lemmatized: s: [Ben] , o: [who] , v: work
# lemmatized&stemmed: s: [ben] , o: [who] , v: work
# phrase triples: [SVOTriple(subject=[Scott], verb=[has], object=[screenplay]), SVOTriple(subject=[he], verb=['s, trying], object=[that, to, get, off, the, ground, ,])]
# raw triples: SVOTriple(subject=[Scott], verb=[has], object=[screenplay])
# lemmatized: s: [Scott] , o: [screenplay] , v: have
# lemmatized&stemmed: s: [scott] , o: [screenplay] , v: ha
# raw triples: SVOTriple(subject=[he], verb=['s, trying], object=[that, to, get, off, the, ground, ,])
# lemmatized: s: [he] , o: [that, to, get, off, the, ground, ,] , v: try
# lemmatized&stemmed: s: [he] , o: [that, to, get, off, the, ground, ,] , v: tri
# phrase triples: [SVOTriple(subject=[studio], verb=[is, threatening], object=[to, cancel, a, planned, Bruce, Willis, movie]), SVOTriple(subject=[he], verb=[has, grown], object=[that])]
# raw triples: SVOTriple(subject=[studio], verb=[is, threatening], object=[to, cancel, a, planned, Bruce, Willis, movie])
# lemmatized: s: [studio] , o: [to, cancel, a, planned, Bruce, Willis, movie] , v: threaten
# lemmatized&stemmed: s: [studio] , o: [to, cancel, a, planned, bruce, willis, movie] , v: threaten
# raw triples: SVOTriple(subject=[he], verb=[has, grown], object=[that])
# lemmatized: s: [he] , o: [that] , v: grow
# lemmatized&stemmed: s: [he] , o: [that] , v: grown
# phrase triples: [SVOTriple(subject=[career, hinges, attempt], verb=[meets], object=[response])]
# raw triples: SVOTriple(subject=[career, hinges, attempt], verb=[meets], object=[response])
# lemmatized: s: [career, hinges, attempt] , o: [response] , v: meet
# lemmatized&stemmed: s: [career, hinges, attempt] , o: [response] , v: meet
# phrase triples: [SVOTriple(subject=[Jeremy, relents, re, -], verb=[edits], object=[ending])]
# raw triples: SVOTriple(subject=[Jeremy, relents, re, -], verb=[edits], object=[ending])
# lemmatized: s: [Jeremy, relents, re, -] , o: [ending] , v: edit
# lemmatized&stemmed: s: [jeremy, relents, re, -] , o: [ending] , v: edit
# phrase triples: [SVOTriple(subject=[Ben], verb=[tries], object=[to, get, Willis, 's, agent, ,, Dick, Bell, ,, to, reason, with, him, and, get, the, beard, removed]), SVOTriple(subject=[efforts, Ben], verb=[get, fired], object=[to, get, Willis, 's, agent, ,, Dick, Bell, ,, to, reason, with, him, and, get, the, beard, removed])]
# raw triples: SVOTriple(subject=[Ben], verb=[tries], object=[to, get, Willis, 's, agent, ,, Dick, Bell, ,, to, reason, with, him, and, get, the, beard, removed])
# lemmatized: s: [Ben] , o: [to, get, Willis, 's, agent, ,, Dick, Bell, ,, to, reason, with, him, and, get, the, beard, removed] , v: try
# lemmatized&stemmed: s: [ben] , o: [to, get, willis, 's, agent, ,, dick, bell, ,, to, reason, with, him, and, get, the, beard, removed] , v: tri
# raw triples: SVOTriple(subject=[efforts, Ben], verb=[get, fired], object=[to, get, Willis, 's, agent, ,, Dick, Bell, ,, to, reason, with, him, and, get, the, beard, removed])
# lemmatized: s: [efforts, Ben] , o: [to, get, Willis, 's, agent, ,, Dick, Bell, ,, to, reason, with, him, and, get, the, beard, removed] , v: fire
# lemmatized&stemmed: s: [efforts, ben] , o: [to, get, willis, 's, agent, ,, dick, bell, ,, to, reason, with, him, and, get, the, beard, removed] , v: fire
# phrase triples: [SVOTriple(subject=[Willis], verb=[does, shave], object=[beard]), SVOTriple(subject=[film], verb=[goes], object=[beard])]
# raw triples: SVOTriple(subject=[Willis], verb=[does, shave], object=[beard])
# lemmatized: s: [Willis] , o: [beard] , v: shave
# lemmatized&stemmed: s: [willis] , o: [beard] , v: shave
# raw triples: SVOTriple(subject=[film], verb=[goes], object=[beard])
# lemmatized: s: [film] , o: [beard] , v: go
# lemmatized&stemmed: s: [film] , o: [beard] , v: go
# phrase triples: [SVOTriple(subject=[Ben, Lou, Jeremy], verb=[attend], object=[Cannes]), SVOTriple(subject=[they], verb=[might, take], object=[D'Or, award])]
# raw triples: SVOTriple(subject=[Ben, Lou, Jeremy], verb=[attend], object=[Cannes])
# lemmatized: s: [Ben, Lou, Jeremy] , o: [Cannes] , v: attend
# lemmatized&stemmed: s: [ben, lou, jeremy] , o: [cannes] , v: attend
# raw triples: SVOTriple(subject=[they], verb=[might, take], object=[D'Or, award])
# lemmatized: s: [they] , o: [D'Or, award] , v: take
# lemmatized&stemmed: s: [they] , o: [d'or, award] , v: take
# phrase triples: []
# Could not detect triples in phrase: Unfortunately, and without telling Ben or Lou, Jeremy has re-edited Fiercely again, not only killing the dog, but adding nearly a full minute of bullets being shot into their bodies
# phrase triples: [SVOTriple(subject=[ending], verb=[destroys], object=[chances]), SVOTriple(subject=[others], verb=[applaud], object=[version])]
# raw triples: SVOTriple(subject=[ending], verb=[destroys], object=[chances])
# lemmatized: s: [ending] , o: [chances] , v: destroy
# lemmatized&stemmed: s: [ending] , o: [chances] , v: destroy
# raw triples: SVOTriple(subject=[others], verb=[applaud], object=[version])
# lemmatized: s: [others] , o: [version] , v: applaud
# lemmatized&stemmed: s: [others] , o: [version] , v: applaud
# phrase triples: []
# Could not detect triples in phrase: Lou is not impressed, and immediately flies out of Cannes on the studio's private jet, leaving Ben stranded in France
# phrase triples: []
# Could not detect triples in phrase: Ben eventually does make it back home, in time for a photo-shoot of Hollywood's top thirty producers with Vanity Fair, although after the magazine's publishers hear about the debacle in Cannes, Ben is relegated to the far edge of the photo, meaning he will be barely noticeable
# phrase triples: []
# Could not detect triples in phrase: The story centers on Larry Stalder, a small-town deputy who dreams of becoming an FBI agent
# phrase triples: []
# Could not detect triples in phrase: He then witnesses what he believes is a kidnapping and rushes to rescue a woman named Madeleine
# phrase triples: [SVOTriple(subject=[kidnappers], verb=[turn], object=[to, be, FBI, agents, assigned, to, protect, her, and, deliver, her, to, a, big, Enron, -, type, corruption, trial, in, Chicago])]
# raw triples: SVOTriple(subject=[kidnappers], verb=[turn], object=[to, be, FBI, agents, assigned, to, protect, her, and, deliver, her, to, a, big, Enron, -, type, corruption, trial, in, Chicago])
# lemmatized: s: [kidnappers] , o: [to, be, FBI, agents, assigned, to, protect, her, and, deliver, her, to, a, big, Enron, -, type, corruption, trial, in, Chicago] , v: turn
# lemmatized&stemmed: s: [kidnappers] , o: [to, be, fbi, agents, assigned, to, protect, her, and, deliver, her, to, a, big, enron, -, type, corruption, trial, in, chicago] , v: turn
# phrase triples: [SVOTriple(subject=[Larry], verb=[attempts], object=[to, deliver, Madeleine, to, the, agents, and, get, a, commendation, letter, from, them, until, he, discovers, that, they, 're, corrupted])]
# raw triples: SVOTriple(subject=[Larry], verb=[attempts], object=[to, deliver, Madeleine, to, the, agents, and, get, a, commendation, letter, from, them, until, he, discovers, that, they, 're, corrupted])
# lemmatized: s: [Larry] , o: [to, deliver, Madeleine, to, the, agents, and, get, a, commendation, letter, from, them, until, he, discovers, that, they, 're, corrupted] , v: attempt
# lemmatized&stemmed: s: [larry] , o: [to, deliver, madeleine, to, the, agents, and, get, a, commendation, letter, from, them, until, he, discovers, that, they, 're, corrupted] , v: attempt
# phrase triples: [SVOTriple(subject=[Madeleine], verb=[is, going], object=[whom, to, testify, against]), SVOTriple(subject=[who], verb=[dumped], object=[her])]
# raw triples: SVOTriple(subject=[Madeleine], verb=[is, going], object=[whom, to, testify, against])
# lemmatized: s: [Madeleine] , o: [whom, to, testify, against] , v: go
# lemmatized&stemmed: s: [madeleine] , o: [whom, to, testify, against] , v: go
# raw triples: SVOTriple(subject=[who], verb=[dumped], object=[her])
# lemmatized: s: [who] , o: [her] , v: dump
# lemmatized&stemmed: s: [who] , o: [her] , v: dump
# phrase triples: [SVOTriple(subject=[Larry, Madeleine], verb=[are, found], object=[agents])]
# raw triples: SVOTriple(subject=[Larry, Madeleine], verb=[are, found], object=[agents])
# lemmatized: s: [Larry, Madeleine] , o: [agents] , v: find
# lemmatized&stemmed: s: [larry, madeleine] , o: [agents] , v: found
# phrase triples: []
# Could not detect triples in phrase: During their journey, they discover that the evidence against Arthur, contained within a disc, was stolen and is inside a safe in Arthur's mansion
# phrase triples: [SVOTriple(subject=[they], verb=[manage], object=[to, keep, the, villains, off, track, by, faking, Madeleine, 's, death])]
# raw triples: SVOTriple(subject=[they], verb=[manage], object=[to, keep, the, villains, off, track, by, faking, Madeleine, 's, death])
# lemmatized: s: [they] , o: [to, keep, the, villains, off, track, by, faking, Madeleine, 's, death] , v: manage
# lemmatized&stemmed: s: [they] , o: [to, keep, the, villains, off, track, by, faking, madeleine, 's, death] , v: manag
# phrase triples: [SVOTriple(subject=[Larry], verb=[enters], object=[charity, polo, match])]
# raw triples: SVOTriple(subject=[Larry], verb=[enters], object=[charity, polo, match])
# lemmatized: s: [Larry] , o: [charity, polo, match] , v: enter
# lemmatized&stemmed: s: [larry] , o: [charity, polo, match] , v: enter
# phrase triples: [SVOTriple(subject=[He], verb=[manages], object=[to, beat, Arthur, ,, who, at, first, denies, to, invite, him, to, the, ball]), SVOTriple(subject=[who], verb=[denies], object=[to, invite, him, to, the, ball]), SVOTriple(subject=[Larry], verb=[convinces], object=[him])]
# raw triples: SVOTriple(subject=[He], verb=[manages], object=[to, beat, Arthur, ,, who, at, first, denies, to, invite, him, to, the, ball])
# lemmatized: s: [He] , o: [to, beat, Arthur, ,, who, at, first, denies, to, invite, him, to, the, ball] , v: manage
# lemmatized&stemmed: s: [he] , o: [to, beat, arthur, ,, who, at, first, denies, to, invite, him, to, the, ball] , v: manag
# raw triples: SVOTriple(subject=[who], verb=[denies], object=[to, invite, him, to, the, ball])
# lemmatized: s: [who] , o: [to, invite, him, to, the, ball] , v: deny
# lemmatized&stemmed: s: [who] , o: [to, invite, him, to, the, ball] , v: deni
# raw triples: SVOTriple(subject=[Larry], verb=[convinces], object=[him])
# lemmatized: s: [Larry] , o: [him] , v: convince
# lemmatized&stemmed: s: [larry] , o: [him] , v: convinc
# phrase triples: []
# Could not detect triples in phrase: At the ball, Larry searches for the disc while Madeleine dances with Arthur to distract him
# phrase triples: [SVOTriple(subject=[Larry], verb=[encounters], object=[Wilford]), SVOTriple(subject=[Larry], verb=[defeats], object=[Wilford])]
# raw triples: SVOTriple(subject=[Larry], verb=[encounters], object=[Wilford])
# lemmatized: s: [Larry] , o: [Wilford] , v: encounter
# lemmatized&stemmed: s: [larry] , o: [wilford] , v: encount
# raw triples: SVOTriple(subject=[Larry], verb=[defeats], object=[Wilford])
# lemmatized: s: [Larry] , o: [Wilford] , v: defeat
# lemmatized&stemmed: s: [larry] , o: [wilford] , v: defeat
# phrase triples: []
# Could not detect triples in phrase: He then bargains with one of the corrupted FBI agents to let him go, in exchange for the money in the safe
# phrase triples: [SVOTriple(subject=[Larry, Madeleine], verb=[manage], object=[to, escape, after, Arthur, easily, deduces, her, identity, and, holds, her, hostage, ,, forcing, Larry, to, give, him, the, disc, to, save, Madeleine]), SVOTriple(subject=[Arthur], verb=[deduces], object=[identity]), SVOTriple(subject=[Arthur], verb=[holds], object=[hostage])]
# raw triples: SVOTriple(subject=[Larry, Madeleine], verb=[manage], object=[to, escape, after, Arthur, easily, deduces, her, identity, and, holds, her, hostage, ,, forcing, Larry, to, give, him, the, disc, to, save, Madeleine])
# lemmatized: s: [Larry, Madeleine] , o: [to, escape, after, Arthur, easily, deduces, her, identity, and, holds, her, hostage, ,, forcing, Larry, to, give, him, the, disc, to, save, Madeleine] , v: manage
# lemmatized&stemmed: s: [larry, madeleine] , o: [to, escape, after, arthur, easily, deduces, her, identity, and, holds, her, hostage, ,, forcing, larry, to, give, him, the, disc, to, save, madeleine] , v: manag
# raw triples: SVOTriple(subject=[Arthur], verb=[deduces], object=[identity])
# lemmatized: s: [Arthur] , o: [identity] , v: deduce
# lemmatized&stemmed: s: [arthur] , o: [identity] , v: deduc
# raw triples: SVOTriple(subject=[Arthur], verb=[holds], object=[hostage])
# lemmatized: s: [Arthur] , o: [hostage] , v: hold
# lemmatized&stemmed: s: [arthur] , o: [hostage] , v: hold
# phrase triples: []
# Could not detect triples in phrase: It is later revealed that the disc Larry gave to Arthur was a video of him singing his favorite country song
# phrase triples: [SVOTriple(subject=[Larry], verb=[is, offered], object=[to, join, the, FBI]), SVOTriple(subject=[he], verb=[turns], object=[it])]
# raw triples: SVOTriple(subject=[Larry], verb=[is, offered], object=[to, join, the, FBI])
# lemmatized: s: [Larry] , o: [to, join, the, FBI] , v: offer
# lemmatized&stemmed: s: [larry] , o: [to, join, the, fbi] , v: offer
# raw triples: SVOTriple(subject=[he], verb=[turns], object=[it])
# lemmatized: s: [he] , o: [it] , v: turn
# lemmatized&stemmed: s: [he] , o: [it] , v: turn
# phrase triples: [SVOTriple(subject=[He, Madeleine], verb=[say], object=[goodbye, part])]
# raw triples: SVOTriple(subject=[He, Madeleine], verb=[say], object=[goodbye, part])
# lemmatized: s: [He, Madeleine] , o: [goodbye, part] , v: say
# lemmatized&stemmed: s: [he, madeleine] , o: [goodbye, part] , v: say
# phrase triples: []
# Could not detect triples in phrase: Upon returning home, Larry becomes the new town sheriff and celebrates with his girlfriend Connie
# phrase triples: []
# Could not detect triples in phrase: Clothing designer Mary Haines lives in a beautiful suburban Connecticut home with her wealthy financier husband Steven and their 11-year-old daughter Molly
# phrase triples: [SVOTriple(subject=[that], verb=[dictates], object=[latest])]
# raw triples: SVOTriple(subject=[that], verb=[dictates], object=[latest])
# lemmatized: s: [that] , o: [latest] , v: dictate
# lemmatized&stemmed: s: [that] , o: [latest] , v: dictat
# phrase triples: [SVOTriple(subject=[who], verb=[discovers], object=[news])]
# raw triples: SVOTriple(subject=[who], verb=[discovers], object=[news])
# lemmatized: s: [who] , o: [news] , v: discover
# lemmatized&stemmed: s: [who] , o: [news] , v: discov
# phrase triples: [SVOTriple(subject=[she], verb=[knows], object=[what]), SVOTriple(subject=[Mary], verb=[confronts], object=[Crystal])]
# raw triples: SVOTriple(subject=[she], verb=[knows], object=[what])
# ...
# lemmatized: s: [wife] , o: [him] , v: leave
# lemmatized&stemmed: s: [wife] , o: [him] , v: left
# phrase triples: []
# Could not detect triples in phrase: Burt and Verona fly to Miami, where Courtney worries about his young daughter and the potential effects of a divorce on her
# phrase triples: [SVOTriple(subject=[Burt], verb=[tries], object=[to, comfort, Courtney]), SVOTriple(subject=[Verona], verb=[spends], object=[time])]
# raw triples: SVOTriple(subject=[Burt], verb=[tries], object=[to, comfort, Courtney])
# lemmatized: s: [Burt] , o: [to, comfort, Courtney] , v: try
# lemmatized&stemmed: s: [burt] , o: [to, comfort, courtney] , v: tri
# raw triples: SVOTriple(subject=[Verona], verb=[spends], object=[time])
# lemmatized: s: [Verona] , o: [time] , v: spend
# lemmatized&stemmed: s: [verona] , o: [time] , v: spend
# phrase triples: [SVOTriple(subject=[Burt, Verona], verb=[spend], object=[night])]
# raw triples: SVOTriple(subject=[Burt, Verona], verb=[spend], object=[night])
# lemmatized: s: [Burt, Verona] , o: [night] , v: spend
# lemmatized&stemmed: s: [burt, verona] , o: [night] , v: spend
# phrase triples: [SVOTriple(subject=[Verona], verb=[tells], object=[story])]
# raw triples: SVOTriple(subject=[Verona], verb=[tells], object=[story])
# lemmatized: s: [Verona] , o: [story] , v: tell
# lemmatized&stemmed: s: [verona] , o: [story] , v: tell
# phrase triples: [SVOTriple(subject=[they], verb=[decide], object=[to, settle, in, Verona, 's, old, family, home, on, the, Florida, Panhandle])]
# raw triples: SVOTriple(subject=[they], verb=[decide], object=[to, settle, in, Verona, 's, old, family, home, on, the, Florida, Panhandle])
# lemmatized: s: [they] , o: [to, settle, in, Verona, 's, old, family, home, on, the, Florida, Panhandle] , v: decide
# lemmatized&stemmed: s: [they] , o: [to, settle, in, verona, 's, old, family, home, on, the, florida, panhandle] , v: decid
# phrase triples: []
# Could not detect triples in phrase: Realizing it is the place for them, they sit together happily, overlooking the water
# phrase triples: []
# Could not detect triples in phrase: In August 2005, Terence McDonagh (Nicolas Cage) is a New Orleans police sergeant
# phrase triples: []
# Could not detect triples in phrase: While cleaning out a locker after Hurricane Katrina, he notices that a prisoner may not have been transferred
# phrase triples: [SVOTriple(subject=[he], verb=[mocks], object=[him])]
# raw triples: SVOTriple(subject=[he], verb=[mocks], object=[him])
# lemmatized: s: [he] , o: [him] , v: mock
# lemmatized&stemmed: s: [he] , o: [him] , v: mock
# phrase triples: [SVOTriple(subject=[He], verb=[is, promoted], object=[back, injury]), SVOTriple(subject=[He], verb=[given], object=[back, injury]), SVOTriple(subject=[He], verb=[has, suffered], object=[back, injury])]
# raw triples: SVOTriple(subject=[He], verb=[is, promoted], object=[back, injury])
# lemmatized: s: [He] , o: [back, injury] , v: promote
# lemmatized&stemmed: s: [he] , o: [back, injury] , v: promot
# raw triples: SVOTriple(subject=[He], verb=[given], object=[back, injury])
# lemmatized: s: [He] , o: [back, injury] , v: give
# lemmatized&stemmed: s: [he] , o: [back, injury] , v: given
# raw triples: SVOTriple(subject=[He], verb=[has, suffered], object=[back, injury])
# lemmatized: s: [He] , o: [back, injury] , v: suffer
# lemmatized&stemmed: s: [he] , o: [back, injury] , v: suffer
# phrase triples: [SVOTriple(subject=[he], verb=[will, need], object=[which, to, take, for, the, rest, of, his, life, to, manage, the, pain])]
# raw triples: SVOTriple(subject=[he], verb=[will, need], object=[which, to, take, for, the, rest, of, his, life, to, manage, the, pain])
# lemmatized: s: [he] , o: [which, to, take, for, the, rest, of, his, life, to, manage, the, pain] , v: need
# lemmatized&stemmed: s: [he] , o: [which, to, take, for, the, rest, of, his, life, to, manage, the, pain] , v: need
# phrase triples: []
# Could not detect triples in phrase: Six months later, McDonagh is now not only addicted to painkillers, but is habitually using several other drugs including cocaine and cannabis
# phrase triples: [SVOTriple(subject=[He], verb=[has, convinced], object=[person])]
# raw triples: SVOTriple(subject=[He], verb=[has, convinced], object=[person])
# lemmatized: s: [He] , o: [person] , v: convince
# lemmatized&stemmed: s: [he] , o: [person] , v: convinc
# phrase triples: [SVOTriple(subject=[girlfriend], verb=[does], object=[cocaine]), SVOTriple(subject=[they], verb=[share], object=[drugs])]
# raw triples: SVOTriple(subject=[girlfriend], verb=[does], object=[cocaine])
# lemmatized: s: [girlfriend] , o: [cocaine] , v: do
# lemmatized&stemmed: s: [girlfriend] , o: [cocaine] , v: doe
# raw triples: SVOTriple(subject=[they], verb=[share], object=[drugs])
# lemmatized: s: [they] , o: [drugs] , v: share
# lemmatized&stemmed: s: [they] , o: [drugs] , v: share
# phrase triples: [SVOTriple(subject=[who], verb=[can, bring], object=[himself])]
# raw triples: SVOTriple(subject=[who], verb=[can, bring], object=[himself])
# lemmatized: s: [who] , o: [himself] , v: bring
# lemmatized&stemmed: s: [who] , o: [himself] , v: bring
# phrase triples: [SVOTriple(subject=[he], verb=[uses], object=[position]), SVOTriple(subject=[he], verb=[steal], object=[drugs])]
# raw triples: SVOTriple(subject=[he], verb=[uses], object=[position])
# lemmatized: s: [he] , o: [position] , v: use
# lemmatized&stemmed: s: [he] , o: [position] , v: us
# raw triples: SVOTriple(subject=[he], verb=[steal], object=[drugs])
# lemmatized: s: [he] , o: [drugs] , v: steal
# lemmatized&stemmed: s: [he] , o: [drugs] , v: steal
# phrase triples: [SVOTriple(subject=[McDonagh], verb=[is, assigned], object=[to, investigate, the, murders, of, five, illegal, immigrants, from, Senegal, ,, who, were, killed, for, selling, drugs, in, a, gang, leader, 's, neighborhood])]
# raw triples: SVOTriple(subject=[McDonagh], verb=[is, assigned], object=[to, investigate, the, murders, of, five, illegal, immigrants, from, Senegal, ,, who, were, killed, for, selling, drugs, in, a, gang, leader, 's, neighborhood])
# lemmatized: s: [McDonagh] , o: [to, investigate, the, murders, of, five, illegal, immigrants, from, Senegal, ,, who, were, killed, for, selling, drugs, in, a, gang, leader, 's, neighborhood] , v: assign
# lemmatized&stemmed: s: [mcdonagh] , o: [to, investigate, the, murders, of, five, illegal, immigrants, from, senegal, ,, who, were, killed, for, selling, drugs, in, a, gang, leader, 's, neighborhood] , v: assign
# phrase triples: [SVOTriple(subject=[gang, leader], verb=[has], object=[associates])]
# raw triples: SVOTriple(subject=[gang, leader], verb=[has], object=[associates])
# lemmatized: s: [gang, leader] , o: [associates] , v: have
# lemmatized&stemmed: s: [gang, leader] , o: [associates] , v: ha
# phrase triples: []
# Could not detect triples in phrase: After both are arrested, Big Fate willingly comes to the police station with his lawyer
# phrase triples: [SVOTriple(subject=[they], verb=[try], object=[to, gather, evidence, against, Big, Fate]), SVOTriple(subject=[Frankie], verb=[beaten], object=[one, man])]
# raw triples: SVOTriple(subject=[they], verb=[try], object=[to, gather, evidence, against, Big, Fate])
# lemmatized: s: [they] , o: [to, gather, evidence, against, Big, Fate] , v: try
# lemmatized&stemmed: s: [they] , o: [to, gather, evidence, against, big, fate] , v: tri
# raw triples: SVOTriple(subject=[Frankie], verb=[beaten], object=[one, man])
# lemmatized: s: [Frankie] , o: [one, man] , v: beat
# lemmatized&stemmed: s: [frankie] , o: [one, man] , v: beaten
# phrase triples: [SVOTriple(subject=[McDonagh], verb=[threatens], object=[Justin]), SVOTriple(subject=[McDonagh], verb=[takes], object=[10,000])]
# raw triples: SVOTriple(subject=[McDonagh], verb=[threatens], object=[Justin])
# lemmatized: s: [McDonagh] , o: [Justin] , v: threaten
# lemmatized&stemmed: s: [mcdonagh] , o: [justin] , v: threaten
# raw triples: SVOTriple(subject=[McDonagh], verb=[takes], object=[10,000])
# lemmatized: s: [McDonagh] , o: [10,000] , v: take
# lemmatized&stemmed: s: [mcdonagh] , o: [10,000] , v: take
# phrase triples: []
# Could not detect triples in phrase: Later on, a delivery boy who was an auditory witness of the murder scene goes missing
# phrase triples: [SVOTriple(subject=[McDonagh], verb=[finds], object=[grandmother]), SVOTriple(subject=[McDonagh], verb=[threatens], object=[to, kill, one, of, her, patients, to, make, her, divulge, where, the, witness, has, gone])]
# raw triples: SVOTriple(subject=[McDonagh], verb=[finds], object=[grandmother])
# lemmatized: s: [McDonagh] , o: [grandmother] , v: find
# lemmatized&stemmed: s: [mcdonagh] , o: [grandmother] , v: find
# raw triples: SVOTriple(subject=[McDonagh], verb=[threatens], object=[to, kill, one, of, her, patients, to, make, her, divulge, where, the, witness, has, gone])
# lemmatized: s: [McDonagh] , o: [to, kill, one, of, her, patients, to, make, her, divulge, where, the, witness, has, gone] , v: threaten
# lemmatized&stemmed: s: [mcdonagh] , o: [to, kill, one, of, her, patients, to, make, her, divulge, where, the, witness, has, gone] , v: threaten
# phrase triples: [SVOTriple(subject=[woman], verb=[has, sent], object=[him])]
# raw triples: SVOTriple(subject=[woman], verb=[has, sent], object=[him])
# lemmatized: s: [woman] , o: [him] , v: send
# lemmatized&stemmed: s: [woman] , o: [him] , v: sent
# phrase triples: []
# Could not detect triples in phrase: In addition to dealing with the murder investigation, McDonagh gets in trouble with his bookie Ned (Brad Dourif) for not paying his debts
# phrase triples: []
# Could not detect triples in phrase: What little money McDonagh has is given to a gangster who works for Justin
# phrase triples: [SVOTriple(subject=[gangster], verb=[requests], object=[amount]), SVOTriple(subject=[gangster], verb=[gives], object=[days])]
# raw triples: SVOTriple(subject=[gangster], verb=[requests], object=[amount])
# lemmatized: s: [gangster] , o: [amount] , v: request
# lemmatized&stemmed: s: [gangster] , o: [amount] , v: request
# raw triples: SVOTriple(subject=[gangster], verb=[gives], object=[days])
# lemmatized: s: [gangster] , o: [days] , v: give
# lemmatized&stemmed: s: [gangster] , o: [days] , v: give
# phrase triples: []
# Could not detect triples in phrase: As a result of his treatment of the old woman, McDonagh is on modified duty and his gun placed in the evidence room
# phrase triples: [SVOTriple(subject=[McDonagh], verb=[supplying], object=[Fate])]
# raw triples: SVOTriple(subject=[McDonagh], verb=[supplying], object=[Fate])
# lemmatized: s: [McDonagh] , o: [Fate] , v: supply
# lemmatized&stemmed: s: [mcdonagh] , o: [fate] , v: suppli
# phrase triples: [SVOTriple(subject=[McDonagh], verb=[has], object=[money]), SVOTriple(subject=[McDonagh], verb=[uses], object=[earnings])]
# raw triples: SVOTriple(subject=[McDonagh], verb=[has], object=[money])
# lemmatized: s: [McDonagh] , o: [money] , v: have
# lemmatized&stemmed: s: [mcdonagh] , o: [money] , v: ha
# raw triples: SVOTriple(subject=[McDonagh], verb=[uses], object=[earnings])
# lemmatized: s: [McDonagh] , o: [earnings] , v: use
# lemmatized&stemmed: s: [mcdonagh] , o: [earnings] , v: us
# phrase triples: []
# Could not detect triples in phrase: During a celebration of the successful partnership between McDonagh and Big Fate, the gangster shows up, demanding his money
# phrase triples: [SVOTriple(subject=[McDonagh], verb=[offers], object=[cut]), SVOTriple(subject=[gangster], verb=[wants], object=[to, take, it, all])]
# raw triples: SVOTriple(subject=[McDonagh], verb=[offers], object=[cut])
# lemmatized: s: [McDonagh] , o: [cut] , v: offer
# lemmatized&stemmed: s: [mcdonagh] , o: [cut] , v: offer
# raw triples: SVOTriple(subject=[gangster], verb=[wants], object=[to, take, it, all])
# lemmatized: s: [gangster] , o: [to, take, it, all] , v: want
# lemmatized&stemmed: s: [gangster] , o: [to, take, it, all] , v: want
# phrase triples: [SVOTriple(subject=[Fate, crew], verb=[end], object=[killing, the, gangsters])]
# raw triples: SVOTriple(subject=[Fate, crew], verb=[end], object=[killing, the, gangsters])
# lemmatized: s: [Fate, crew] , o: [killing, the, gangsters] , v: end
# lemmatized&stemmed: s: [fate, crew] , o: [killing, the, gangsters] , v: end
# phrase triples: [SVOTriple(subject=[McDonagh], verb=[implores], object=[Big, Fate])]
# raw triples: SVOTriple(subject=[McDonagh], verb=[implores], object=[Big, Fate])
# lemmatized: s: [McDonagh] , o: [Big, Fate] , v: implore
# lemmatized&stemmed: s: [mcdonagh] , o: [big, fate] , v: implor
# phrase triples: [SVOTriple(subject=[He], verb=[does], object=[pipe]), SVOTriple(subject=[McDonagh], verb=[plants], object=[pipe])]
# raw triples: SVOTriple(subject=[He], verb=[does], object=[pipe])
# lemmatized: s: [He] , o: [pipe] , v: do
# lemmatized&stemmed: s: [he] , o: [pipe] , v: doe
# raw triples: SVOTriple(subject=[McDonagh], verb=[plants], object=[pipe])
# lemmatized: s: [McDonagh] , o: [pipe] , v: plant
# lemmatized&stemmed: s: [mcdonagh] , o: [pipe] , v: plant
# phrase triples: [SVOTriple(subject=[department], verb=[uses], object=[evidence]), SVOTriple(subject=[department], verb=[threatens], object=[to, kill, Big, Fate, ,]), SVOTriple(subject=[him], verb=[to, have], object=[chance])]
# raw triples: SVOTriple(subject=[department], verb=[uses], object=[evidence])
# lemmatized: s: [department] , o: [evidence] , v: use
# lemmatized&stemmed: s: [department] , o: [evidence] , v: us
# raw triples: SVOTriple(subject=[department], verb=[threatens], object=[to, kill, Big, Fate, ,])
# lemmatized: s: [department] , o: [to, kill, Big, Fate, ,] , v: threaten
# lemmatized&stemmed: s: [department] , o: [to, kill, big, fate, ,] , v: threaten
# raw triples: SVOTriple(subject=[him], verb=[to, have], object=[chance])
# lemmatized: s: [him] , o: [chance] , v: have
# lemmatized&stemmed: s: [him] , o: [chance] , v: have
# phrase triples: [SVOTriple(subject=[he], verb=[can, perform], object=[duties])]
# raw triples: SVOTriple(subject=[he], verb=[can, perform], object=[duties])
# lemmatized: s: [he] , o: [duties] , v: perform
# lemmatized&stemmed: s: [he] , o: [duties] , v: perform
# phrase triples: []
# Could not detect triples in phrase: McDonagh is later promoted to police captain
# phrase triples: [SVOTriple(subject=[McDonagh], verb=[appears], object=[to, be, sober]), SVOTriple(subject=[it], verb=[turns], object=[to, be, sober])]
# raw triples: SVOTriple(subject=[McDonagh], verb=[appears], object=[to, be, sober])
# lemmatized: s: [McDonagh] , o: [to, be, sober] , v: appear
# lemmatized&stemmed: s: [mcdonagh] , o: [to, be, sober] , v: appear
# raw triples: SVOTriple(subject=[it], verb=[turns], object=[to, be, sober])
# lemmatized: s: [it] , o: [to, be, sober] , v: turn
# lemmatized&stemmed: s: [it] , o: [to, be, sober] , v: turn
# phrase triples: [SVOTriple(subject=[He], verb=[encounters], object=[prisoner]), SVOTriple(subject=[he], verb=[saved], object=[whom]), SVOTriple(subject=[man], verb=[exclaims], object=[prisoner]), SVOTriple(subject=[McDonagh], verb=[saved], object=[life])]
# raw triples: SVOTriple(subject=[He], verb=[encounters], object=[prisoner])
# lemmatized: s: [He] , o: [prisoner] , v: encounter
# lemmatized&stemmed: s: [he] , o: [prisoner] , v: encount
# raw triples: SVOTriple(subject=[he], verb=[saved], object=[whom])
# lemmatized: s: [he] , o: [whom] , v: save
# lemmatized&stemmed: s: [he] , o: [whom] , v: save
# raw triples: SVOTriple(subject=[man], verb=[exclaims], object=[prisoner])
# lemmatized: s: [man] , o: [prisoner] , v: exclaim
# lemmatized&stemmed: s: [man] , o: [prisoner] , v: exclaim
# raw triples: SVOTriple(subject=[McDonagh], verb=[saved], object=[life])
# lemmatized: s: [McDonagh] , o: [life] , v: save
# lemmatized&stemmed: s: [mcdonagh] , o: [life] , v: save
# phrase triples: [SVOTriple(subject=[McDonagh], verb=[escape], object=[addiction])]
# raw triples: SVOTriple(subject=[McDonagh], verb=[escape], object=[addiction])
# lemmatized: s: [McDonagh] , o: [addiction] , v: escape
# lemmatized&stemmed: s: [mcdonagh] , o: [addiction] , v: escap
# phrase triples: [SVOTriple(subject=[fish], verb=[Do, have], object=[dreams])]
# raw triples: SVOTriple(subject=[fish], verb=[Do, have], object=[dreams])
# lemmatized: s: [fish] , o: [dreams] , v: have
# lemmatized&stemmed: s: [fish] , o: [dreams] , v: have

# %%
print('Triples Detection Rate:', (found_triples_counter / phrase_c))
